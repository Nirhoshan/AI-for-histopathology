# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import cv2
file_path='nct4.csv'
df = pd.read_csv(file_path)
df=np.array(df)
#print(df)
folder_path='/n/holyscratch01/wadduwage_lab/Nirho/'
fig, axs = plt.subplots(2, 2, figsize=(12, 12))
image_path=folder_path+df[0][1]
img=cv2.imread(image_path)
axs[0, 0].imshow(img)
axs[0, 0].set_title('Image 1')
image_path=folder_path+df[1][1]
img=cv2.imread(image_path)
axs[0, 1].imshow(img)
axs[0, 1].set_title('Image 2')
image_path=folder_path+df[2][1]
img=cv2.imread(image_path)
axs[1, 0].imshow(img)
axs[1, 0].set_title('Image 3')
image_path=folder_path+df[3][1]
img=cv2.imread(image_path)
axs[1, 1].imshow(img)
axs[1, 1].set_title('Image 4')
# Out:
# Text(0.5, 1.0, 'Image 4')

# %%
# %run inferen.py --dataset "nct100k" --uncertainty True --num_classes 9 --data_input_dir "/n/holyscratch01/wadduwage_lab/Nirho" --batch_size 1  --training_data_csv "nct4.csv" --validation_data_csv "nct4.csv" --test_data_csv "nct4.csv" --save_dir result --model_path distilled_model.pth
# Out:
# Device: cuda:0
# /n/home02/snirhoshan/.conda/envs/evident2/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /n/home02/snirhoshan/.conda/envs/evident2/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Let's use 4 GPUs!
# opt.data_input_dir:  /n/holyscratch01/wadduwage_lab/Nirho
# opt.data_input_dir_test:  /n/holyscratch01/wadduwage_lab/Nirho
# reading csv file:  nct4.csv
# reading csv file:  nct4.csv
# reading csv file:  nct4.csv
# training patches:  label
# ADI    4
# dtype: int64
# Validation patches:  label
# ADI    4
# dtype: int64
# Test patches:  label
# ADI    4
# dtype: int64
# ...
